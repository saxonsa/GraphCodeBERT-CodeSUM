# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install pandas

# %%
pip install matplotlib

# %%
data = pd.read_csv('java/loss_bleu.csv')

# Extract the columns
x = data.iloc[:, 0]
y1 = data.iloc[:, 1]
y2 = data.iloc[:, 2]

# Create the first figure and axes
fig1, ax1 = plt.subplots(figsize=(4, 4))

# Plot the first line chart
ax1.plot(x, y1)
ax1.set_xlabel('epochs')
ax1.set_ylabel('Loss')
ax1.set_title('Loss trend training on Java dataset')

# Save the first plot to a PDF file
fig1.savefig("java/loss_trend.pdf", format='pdf')

# Close the first plot to release memory
# plt.close(fig1)

# Create the second figure and axes
fig2, ax2 = plt.subplots(figsize=(4, 4))

# Plot the second line chart
ax2.plot(x, y2)
ax2.set_xlabel('epochs')
ax2.set_ylabel('Smooth BLEU-4')
ax2.set_title('Smooth BLEU-4 trend training on Java dataset')

# Save the second plot to a PDF file
fig2.savefig("java/smooth_bleu4_trend.pdf", format='pdf')

# Close the second plot to release memory
# plt.close(fig2)
